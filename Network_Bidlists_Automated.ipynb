# %%
"""
Author: Brent Glassman
1. Queries frequence_network_details for updated domains
2. Check to see if domains are valid
3. Pull Network bidlists and check to see if they need to be updated based on if there is any difference between the new sites and the bidlists
4. Update Networks' bidlists that have new sites 

"""
import pandas as pd
import time
import sys
import numpy as np
sys.path.append(r"../../Desktop/performance_team_bidlist_code/")

import APIs.TTD_API_Library as tal
import APIs.Brandcdn_Library as blib

import json
import requests
# import os
# from pandas.io.json import json_normalize
import re
import datetime
cur_day = datetime.datetime.utcnow().strftime("%m/%d/%y")

# %%
prod_query = """
select fnd.network_name as network_name
,nm.domain as domain
,nm.frequence_network_id as network_id
FROM brandcdn.frequence_network_details fnd
JOIN brandcdn.ctv_site_to_network_and_aggregator_mapping nm
ON nm.frequence_network_id=fnd.id
ORDER BY 1
"""
bidlists_query = """
select *
FROM frequence_network_join_bidlist
"""

# %%
df2 = blib.bcdn_select_query(prod_query, connection = blib.bcdn_connection())
df3 = blib.bcdn_select_query(bidlists_query, connection = blib.bcdn_connection())

# %%
df3 = df3[df3.columns[1:]] # Get rid of some random Ids column

# %%
df_use = df3.merge(df2, how = 'left', on = 'network_id')
df_use = df_use[df_use['domain'].notna()]
df_use
# Out:
#        network_id bidlist_id  \
# 0            1250   65701680
# 1            1250   65701680
# 2             175   65701681
# 3             175   65701681
# 4             175   65701681
# ...           ...        ...
# 24787         720   71183300
# 24790         862   71183365
# 24791         862   71183366
# 24814        1064   71186286
# 24815        1064   71186281
#
#                                             bidlist_name bidlist_type  \
# 0            Network BlockList WDBJ News Test 2020/11/17    BlockList
# 1            Network BlockList WDBJ News Test 2020/11/17    BlockList
# 2              Network BlockList History Test 2020/11/17    BlockList
# 3              Network BlockList History Test 2020/11/17    BlockList
# 4              Network BlockList History Test 2020/11/17    BlockList
# ...                                                  ...          ...
# 24787   Network - 10 News, Type - TargetList, 2020/12/18   TargetList
# 24790  Network - American Heroes Channel, Type - Targ...   TargetList
# 24791  Network - American Heroes Channel, Type - Bloc...    BlockList
# 24814  Network - Nickelodeon, Type - BlockList, 2020/...    BlockList
# 24815  Network - Nickelodeon, Type - TargetList, 2020...   TargetList
#
#         created_timestamp   updated_timestamp     network_name  \
# 0     2020-12-11 00:03:59 2020-12-11 00:03:59        WDBJ News
# 1     2020-12-11 00:03:59 2020-12-11 00:03:59        WDBJ News
# 2     2020-12-11 00:03:59 2020-12-11 00:03:59          History
# 3     2020-12-11 00:03:59 2020-12-11 00:03:59          History
# 4     2020-12-11 00:03:59 2020-12-11 00:03:59          History
# ...                   ...                 ...              ...
# 24787 2021-02-03 00:55:15 2021-02-03 00:55:15          10 News
# 24790 2021-03-25 18:22:18 2021-03-25 18:22:18  American Heroes
# 24791 2021-03-25 18:22:18 2021-03-25 18:22:18  American Heroes
# 24814 2021-03-26 01:20:07 2021-03-26 01:20:07         Nick Jr.
# 24815 2021-03-26 01:20:07 2021-03-26 01:20:07         Nick Jr.
#
#                                        domain
# 0                           com.roku.wdbjnews
# 1                         com.graytv.wdbjnews
# 2            com.sling.otto_roku_history_live
# 3      com.sling.otto_android_tv_history_live
# 4                  com.history.chromecast.app
# ...                                       ...
# 24787                              com.10news
# 24790                      americanheroes.com
# 24791                      americanheroes.com
# 24814                  firetv.fubotv.nick jr.
# 24815                  firetv.fubotv.nick jr.
#
# [24790 rows x 8 columns]

# %%
supply_vendors = pd.read_csv('../assemblingbidlistsandtesting/SupplyVendorNames.csv')
adformats = pd.read_csv('../assemblingbidlistsandtesting/AdFormat.csv')
dimension_translation = {'Supply_Vendor': 'SupplyVendorId',  # Pull from a csv
                        'Fold': 'PlacementPositionRelativeToFold',  # Use the translation below
                        'Browser': 'Browser',  # Use the translation below
                        'Operating_System': 'Os',   # Use the translation below
                        'site': "DomainFragment",  # Use the default cut-off-validation
                        'adformat': 'AdFormatId',  # Pull from a csv
                         'renderingcontext': 'RenderingContext',
                        'devicename': 'DeviceType',  # Default
                         'supplyvendorpublisherid': "PublisherId"
                        }

bidline_translation = {'Fold': {'Above': ['Above'],
                                'Below': ['Below'], 
                                'Unknown': ['Unknown'], 
                                'Other': ['Any']
                               },
                       'DeviceType': {'Mobile': ['Mobile'],
                                'Tablet': ['Tablet'], 
                                'PC': ['Pc']
                               },
                        'Browser': {'Internet_Explorer_Old': ['InternetExplorer7', 'InternetExplorer8', 'InternetExplorer9'],
                                    'FireFox': ['Firefox'],
                                    'Chrome': ['Chrome'],
                                    'Safari': ['Safari'],
                                    'Opera': ['Opera'],
                                    'Internet_Explorer_New': ['InternetExplorer10', 'InternetExplorer11'],
                                    'Edge': ['Edge'],
                                    'Baidu': ['Baidu'],
                                    'Yandex': ['Yandex'],
                                    'WebView': ['WebView'],
                                     'Other': ['Other' , 'InApp']
                                   },
                        'Operating_System': {'Windows': ['WindowsAll','WindowsXP','WindowsVista','Windows7','Windows8','Windows10'],
                                            'OS X': ['OSXAll'],
                                            'Linux': ['LinuxAll'],
                                            'iOS': ['iOS51','iOS60','iOS61','iOS70','iOS71','iOS80','iOS81','iOS82',
                                                    'iOS83','iOS84','iOS90','iOS91','iOS92','iOS93','iOS100','iOS101',
                                                    'iOS102','iOS103','iOS110','iOS111','iOS112','iOS113','iOS120','iOS121',
                                                    'iOS122','iOS123','iOS124','iOS130','iOS131','iOS132','iOS133','iOS134',
                                                    'iOS140','iOS141','iOS142','iOS143','iOS135', 'iOSAll'],
                                            'Android': ['Android23','Android40','Android41','Android42','Android43',
                                                        'Android44','Android50','Android60','Android70', 'Android71',
                                                        'Android51','Android80','Android81','Android90','Android100',
                                                        'Android110','AndroidAll'],
                                            'Windows Phone': ['WindowsPhone80','WindowsPhone81', 'WindowsPhoneAll'],
                                            'Other': ['Other', 'OtherAll']}
                        }
def check_valid(domain):
    if_valid = True
    
    # getting rid of the part after the first '/'
    domain = str(domain).split('/')[0]
    
    # and check if the remaining contains any non-alphanumeric characters besides '.' and '-'
    if not domain.replace('.', '').replace('-', '').replace('_','').isalnum():
        if_valid = False
    elif domain[0] in ('.', '-','_') or domain[-1] in ('.', '-','_'):
        # do not allow '.' or '-' at the beginning or ending
        if_valid = False
    
    return if_valid

def make_payload(li, qa = None, bidlist_type = 'BlockList',Network = None):
    
    if bidlist_type == 'BlockList':
        bid_adjustment = 0
    elif bidlist_type == 'TargetList':
        bid_adjustment = 1
    
    payload_list = []
    #for i in range(len(li)):
    for i in range(1):
        #df = li[i]
        df = li
        d1 = df.columns[0]
        dt1 = dimension_translation[d1] # Get the dimension name
        
        if qa:
            bidlist_name = 'High CTR Global {}_{}_{} QAIV60 Rank{} {} 2020/{}'.format(d1, i+1, bidlist_type, cur_day)
        if not qa:
            #bidlist_name = 'High CTR Global {}_{}_{} Rank{} {} 2020/{}'.format(d1, d2, d3, i+1, bidlist_type, cur_day)
            bidlist_name = 'Network - {}, Type - {}, 2020/{}'.format(Network,bidlist_type, cur_day)

            
        partner_id = 'nc31odz'
        bidlines = []
        for i in range(len(df)):
            # Get translation for dimensions
            c1 = df.loc[i, d1]
            #c2 = df.loc[i, d2]
            #c3 = df.loc[i, d3]
            
            if d1 == "site":
                if check_valid(c1.split('/')[0]):
                    content1 = [c1.split('/')[0]]
                else:
                    content1 = []
                
            for i1 in content1:
                if qa:
                    bidline = {"BidAdjustment": bid_adjustment,
                               "DisplayViewabilityScoreRange": {
                                                                    "Min": qa,
                                                                    "Max": 1
                                                                },
                               dt1: i1}
                               #,dt3: i3}
                else:
                    bidline = {"BidAdjustment": bid_adjustment,
                               dt1: i1}
                               #,dt3: i3}
                if bidline not in bidlines:
                    bidlines.append(bidline)

        payload = {"Name": bidlist_name,
              "BidListAdjustmentType": bidlist_type,
               "ResolutionType": "ApplyMultiplyAdjustment",
              "BidLines": bidlines,
              "BidListOwner": "Partner",
              "BidListOwnerId": partner_id,
              "IsAvailableForLibraryUse": True
            }
        payload_list.append(json.dumps(payload))
    return payload_list

# %%
df = df_use
print(len(df['network_name'].unique()), "Unique Networks")
df['valid'] = [check_valid(val) for val in df['domain']]
cond = df['valid'] # Only include valid domains
# Out:
# 548 Unique Networks

# %%
df = df[cond]
df = df.rename(columns = {'domain':'site'})
df = df.reset_index(drop=True)
df
# Out:
#        network_id bidlist_id  \
# 0            1250   65701680
# 1            1250   65701680
# 2             175   65701681
# 3             175   65701681
# 4             175   65701681
# ...           ...        ...
# 22953         557   71189267
# 22954         720   71183300
# 22955         720   71183300
# 22956         862   71183365
# 22957         862   71183366
#
#                                             bidlist_name bidlist_type  \
# 0            Network BlockList WDBJ News Test 2020/11/17    BlockList
# 1            Network BlockList WDBJ News Test 2020/11/17    BlockList
# 2              Network BlockList History Test 2020/11/17    BlockList
# 3              Network BlockList History Test 2020/11/17    BlockList
# 4              Network BlockList History Test 2020/11/17    BlockList
# ...                                                  ...          ...
# 22953       Network - Zoom, Type - BlockList, 2020/12/18    BlockList
# 22954   Network - 10 News, Type - TargetList, 2020/12/18   TargetList
# 22955   Network - 10 News, Type - TargetList, 2020/12/18   TargetList
# 22956  Network - American Heroes Channel, Type - Targ...   TargetList
# 22957  Network - American Heroes Channel, Type - Bloc...    BlockList
#
#         created_timestamp   updated_timestamp     network_name  \
# 0     2020-12-11 00:03:59 2020-12-11 00:03:59        WDBJ News
# 1     2020-12-11 00:03:59 2020-12-11 00:03:59        WDBJ News
# 2     2020-12-11 00:03:59 2020-12-11 00:03:59          History
# 3     2020-12-11 00:03:59 2020-12-11 00:03:59          History
# 4     2020-12-11 00:03:59 2020-12-11 00:03:59          History
# ...                   ...                 ...              ...
# 22953 2021-02-02 21:55:42 2021-02-02 21:55:42             Zoom
# 22954 2021-02-03 00:55:15 2021-02-03 00:55:15          10 News
# 22955 2021-02-03 00:55:15 2021-02-03 00:55:15          10 News
# 22956 2021-03-25 18:22:18 2021-03-25 18:22:18  American Heroes
# 22957 2021-03-25 18:22:18 2021-03-25 18:22:18  American Heroes
#
#                                          site  valid
# 0                           com.roku.wdbjnews   True
# 1                         com.graytv.wdbjnews   True
# 2            com.sling.otto_roku_history_live   True
# 3      com.sling.otto_android_tv_history_live   True
# 4                  com.history.chromecast.app   True
# ...                                       ...    ...
# 22953           com.sling.otto_tvos_zoom_live   True
# 22954                             roku.10news   True
# 22955                              com.10news   True
# 22956                      americanheroes.com   True
# 22957                      americanheroes.com   True
#
# [22958 rows x 9 columns]

# %%
d_IdNetwork = dict(zip(df.bidlist_id, df.network_name)) # {Bidlistid : NetworkName}

# %%
bidlistIds = df['bidlist_id'].unique() # Unique bidlists to check and update

# %%
auth_token = tal.authenticate(login = 'ttd_api_nc31odz@frequence.com', password = '6}YKJK0L=/dHyK')
# Out:
# Step 1: Acquire authentication token
# Posting authentication request to https://api.thetradedesk.com/v3/authentication...
# Got auth token: GeCkBuICHhDUGN3BKXLxuJkonYmMLmoTPATaNgxD+DS6RyadkfbsnomgNTE6wF4CjzT1e9uXyIs5sjI8FniQXA==

# %% [markdown]
# # Quick Warning, If you start seeing messages like this:
# Program paused for 10 sec.
# Program paused for 20 sec.
#
# That means you're trying to update a bidlist that's invalid. Need to break out of look and figure out why the new bidlist is weird.

# %%
# Check Each Bidlist ID For Updated Sitelist. Push new Payload of new
for i in range(len(bidlistIds)):
    if(i%20==0):
        print(i, ' / ', len(bidlistIds),' done')
    payload = tal.get_bidlist_payload(bidlistIds[i], auth_token) # Pull bidlist from TTD
    payload = payload[1] # Grabs payload part
    
    sites = list(df[df['bidlist_id'] == bidlistIds[i]]['site']) # Gets updated list of network sites from query
    bl_type = df[df['bidlist_id'] == bidlistIds[i]]['bidlist_type'].unique()[0] # Is this bidlist a blocklist or targetlist? returns 'Blocklist' or 'Targetlist'
    name_output = 'Network ' + bl_type + ' - ' + d_IdNetwork[bidlistIds[i]] + ' - ' + cur_day # Makes a new name with the update date for the network list
    
    new_bl = [{'BidAdjustment': 1.0 if bl_type=='TargetList' else 0.0, 'DomainFragment': x,'VolumeControlPriority': 'Neutral'} for x in sites] # NEW BIDLINES
    
    # Compare oldsites and newsites. If they're the same no need to update with a new payload
    oldsites = set([x['DomainFragment'] for x in payload['BidLines']])
    newsites = set(sites)
    if(len(newsites - oldsites)==0):
        continue
    
    # replace old bidlines and Name
    payload['BidLines'] = new_bl # NEW PAYLOAD
    payload['Name'] = name_output # NEW NAME
    
    new = json.dumps(payload) # NEW PAYLOAD IN JSON
    tal.update_ttd_bidlist(new, auth_token) # Push new payload to TTD
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100

# %% [markdown]
# # Just if you're curious, It doesn't appear that domains with spaces are valid. Believe me I've tried

# %% [markdown]
# # Check on individual bidlists here if there are any issues

# %%
i=764 # find the bidlist id you want to check using np.where(bidlistIds == 'your bidlist id here')
payload = tal.get_bidlist_payload(bidlistIds[i], auth_token) # Pull bidlist from TTD
payload = payload[1] # Grabs payload part
oldsites = set([x['DomainFragment'] for x in payload['BidLines']])
oldsites
# Out:
# {'35059',
#  '576009463',
#  'att.mobile.history',
#  'att.ott.history',
#  'b00e5nh46q',
#  'com-roku-hist.app',
#  'com.ae.history',
#  'com.ae.history.appletv',
#  'com.ae.history.chromecast',
#  'com.ae.history.roku',
#  'com.ae.history.samsung',
#  'com.aetn-history-watch.app',
#  'com.aetn.history.ios.watch',
#  'com.aetn.history.watch',
#  'com.aetn.ios.historyvault',
#  'com.appletv.history',
#  'com.chromecast-history.app',
#  'com.fubotv.firetv.historychannel',
#  'com.fubotv.roku.historychannel',
#  'com.history.appletv.app',
#  'com.history.channel.documentaries.history.videos',
#  'com.history.chromecast.app',
#  'com.history.firetv.app',
#  'com.history.mvpd.ctv',
#  'com.history.mvpd.ctvapp',
#  'com.history.roku.app',
#  'com.history.smarttv.app',
#  'com.roku-history.app',
#  'com.roku.history',
#  'com.sling.otto_airtvplayer_history_live',
#  'com.sling.otto_airtvplayer_history_vod',
#  'com.sling.otto_amazon_tablet_history_live',
#  'com.sling.otto_amazon_tablet_history_vod',
#  'com.sling.otto_amazon_tv_history_live',
#  'com.sling.otto_amazon_tv_history_vod',
#  'com.sling.otto_android_tv_history_live',
#  'com.sling.otto_android_tv_history_vod',
#  'com.sling.otto_chromecast_history_live',
#  'com.sling.otto_chromecast_history_vod',
#  'com.sling.otto_lg_history_live',
#  'com.sling.otto_lg_history_vod',
#  'com.sling.otto_roku_history_live',
#  'com.sling.otto_roku_history_vod',
#  'com.sling.otto_samsung_history_live',
#  'com.sling.otto_samsung_history_vod',
#  'com.sling.otto_tvos_history_live',
#  'com.sling.otto_tvos_history_vod',
#  'com.sling.otto_xbox1_history_live',
#  'com.sling.otto_xbox1_history_vod',
#  'com.slingtv.ctv.history.android.tv',
#  'com.slingtv.ctv.history.apple.tv',
#  'com.slingtv.ctv.history.chromecast',
#  'com.slingtv.ctv.history.lg.tv',
#  'com.slingtv.ctv.history.roku',
#  'com.slingtv.ctv.history.xbox.one',
#  'com.slingtv.history.ctv.history.samsung.tv',
#  'com.xumo.aenetworkhistory',
#  'com.xumo.aenetworkthehistorychannel',
#  'com.xumo.com.xumo.aenetworkthehistorychannel',
#  'dish.stb.dish_stb_history_vod',
#  'fubo.tv_104898',
#  'history.tubi.ctv.vod',
#  'historychannel.com',
#  'roku.fubotv.104898',
#  'www.history.com'}

# %%
sites = list(df[df['bidlist_id'] == bidlistIds[i]]['site'])
bl_type = df[df['bidlist_id'] == bidlistIds[i]]['bidlist_type'].unique()[0] #blocklist or targetlist
name_output = 'Network ' + bl_type + ' - ' + d_IdNetwork[bidlistIds[i]] + ' - ' + cur_day

# %%
new_bl = [{'BidAdjustment': 1.0 if bl_type=='TargetList' else 0.0, 'DomainFragment': x,'VolumeControlPriority': 'Neutral'} for x in sites] # NEW BIDLINES

# %%
payload['BidLines'] = new_bl # NEW PAYLOAD
payload['Name'] = name_output

# %%
newsites = set(sites)
print(len(newsites - oldsites), 'new domains')
# Out:
# 0 new domains

# %%
new = json.dumps(payload) # NEW PAYLOAD IN JSON
new
# Out:
# '{"IsGlobal": false, "BidListDimensions": ["HasDomainFragmentId"], "BidListType": "BidAdjustment", "BidListId": "71184824", "Name": "Network BlockList - History - 05/19/22", "BidListSource": "User", "BidListAdjustmentType": "BlockList", "ResolutionType": "ApplyMultiplyAdjustment", "BidLines": [{"BidAdjustment": 0.0, "DomainFragment": "com.sling.otto_roku_history_live", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.sling.otto_android_tv_history_live", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.history.chromecast.app", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.xumo.aenetworkthehistorychannel", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.fubotv.roku.historychannel", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.history.mvpd.ctvapp", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "www.history.com", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.sling.otto_lg_history_vod", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.slingtv.ctv.history.chromecast", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.slingtv.ctv.history.xbox.one", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.aetn.history.ios.watch", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.roku-history.app", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.sling.otto_amazon_tv_history_live", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "fubo.tv_104898", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.aetn.ios.historyvault", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "b00e5nh46q", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "history.tubi.ctv.vod", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.sling.otto_tvos_history_vod", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.ae.history.chromecast", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com-roku-hist.app", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "35059", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.sling.otto_samsung_history_vod", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.fubotv.firetv.historychannel", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.sling.otto_roku_history_vod", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "att.mobile.history", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.roku.history", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.history.appletv.app", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.xumo.aenetworkhistory", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.sling.otto_chromecast_history_live", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "dish.stb.dish_stb_history_vod", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.sling.otto_android_tv_history_vod", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.history.firetv.app", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.history.roku.app", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFragment": "com.slingtv.ctv.history.android.tv", "VolumeControlPriority": "Neutral"}, {"BidAdjustment": 0.0, "DomainFrag ...

# %%
tal.update_ttd_bidlist(new, auth_token)
# Out:
# (True,
#  {'IsGlobal': False,
#   'BidListDimensions': ['HasDomainFragmentId'],
#   'BidListType': 'BidAdjustment',
#   'BidListId': '71184824',
#   'Name': 'Network BlockList - History - 05/19/22',
#   'BidListSource': 'User',
#   'BidListAdjustmentType': 'BlockList',
#   'ResolutionType': 'ApplyMultiplyAdjustment',
#   'BidLines': [{'BidLineId': '4544470669',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'www.history.com',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470670',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.slingtv.ctv.history.roku',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470671',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.ae.history',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470672',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.history.mvpd.ctvapp',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470673',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.slingtv.ctv.history.android.tv',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470674',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com-roku-hist.app',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470675',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.roku.history',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470676',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.aetn.history.watch',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470677',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.appletv.history',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470678',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.history.chromecast.app',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470679',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.chromecast-history.app',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470680',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.aetn.history.ios.watch',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470681',
#     'BidAdjustment': 0.0,
#     'DomainFragment': '576009463',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470682',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.aetn-history-watch.app',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470683',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.slingtv.ctv.history.apple.tv',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470684',
#     'BidAdjustment': 0.0,
#     'DomainFragment': '35059',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470685',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'b00e5nh46q',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470686',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.history.appletv.app',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470687',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.history.firetv.app',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470688',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.roku-history.app',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470689',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.slingtv.ctv.history.chromecast',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470690',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.slingtv.history.ctv.history.samsung.tv',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470691',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.slingtv.ctv.history.lg.tv',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470692',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.xumo.aenetworkthehistorychannel',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470693',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.history.roku.app',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470694',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.aetn.ios.historyvault',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470695',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'roku.fubotv.104898',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470696',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.slingtv.ctv.history.xbox.one',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470697',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'att.ott.history',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470698',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'att.mobile.history',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470699',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.history.channel.documentaries.history.videos',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470700',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.fubotv.roku.historychannel',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470701',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.history.smarttv.app',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470702',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.fubotv.firetv.historychannel',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470703',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.xumo.aenetworkhistory',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470704',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'history.tubi.ctv.vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470705',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.ae.history.roku',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470706',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.history.mvpd.ctv',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470707',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.ae.history.appletv',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470708',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.ae.history.chromecast',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470709',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.xumo.com.xumo.aenetworkthehistorychannel',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '4544470710',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.ae.history.samsung',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771711',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_android_tv_history_live',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771712',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_roku_history_live',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771713',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_tvos_history_live',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771714',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'historychannel.com',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771715',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_android_tv_history_vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771716',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_airtvplayer_history_live',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771717',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_airtvplayer_history_vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771718',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_chromecast_history_live',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771719',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_chromecast_history_vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771720',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_lg_history_live',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771721',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_lg_history_vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771722',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_roku_history_vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771723',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_tvos_history_vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771724',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_samsung_history_live',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771725',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_samsung_history_vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771726',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_xbox1_history_live',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771727',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_xbox1_history_vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771728',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'fubo.tv_104898',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771729',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_amazon_tv_history_live',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771730',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_amazon_tv_history_vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771731',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_amazon_tablet_history_live',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771732',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'com.sling.otto_amazon_tablet_history_vod',
#     'VolumeControlPriority': 'Neutral'},
#    {'BidLineId': '9423771733',
#     'BidAdjustment': 0.0,
#     'DomainFragment': 'dish.stb.dish_stb_history_vod',
#     'VolumeControlPriority': 'Neutral'}],
#   'BidListOwner': 'Partner',
#   'BidListOwnerId': 'nc31odz',
#   'IsAvailableForLibraryUse': True})
